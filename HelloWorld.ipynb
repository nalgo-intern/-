# %% [markdown]
# <a href="https://colab.research.google.com/github/nalgo-intern/-/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hello = "Hello"
world = "World"
print(f'{hello},{world}.')
# Out:
# Hello,World.
